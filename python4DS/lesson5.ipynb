# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
data=pd.read_csv("input/train.csv")

# %%
data.shape
# Out:
# (10000, 20)

# %%
data.columns
# Out:
# Index(['Id', 'DistrictId', 'Rooms', 'Square', 'LifeSquare', 'KitchenSquare',
#        'Floor', 'HouseFloor', 'HouseYear', 'Ecology_1', 'Ecology_2',
#        'Ecology_3', 'Social_1', 'Social_2', 'Social_3', 'Healthcare_1',
#        'Helthcare_2', 'Shops_1', 'Shops_2', 'Price'],
#       dtype='object')

# %%
data.head(10)
# Out:
#       Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0  14038          35    2.0  47.981561   29.442751            6.0      7
# 1  15053          41    3.0  65.683640   40.049543            8.0      7
# 2   4765          53    2.0  44.947953   29.197612            0.0      8
# 3   5809          58    2.0  53.352981   52.731512            9.0      8
# 4  10783          99    1.0  39.649192   23.776169            7.0     11
# 5  12915          59    3.0  80.384479   46.683720           12.0      5
# 6  14549         154    2.0  62.254114   37.160377            7.0      3
# 7  11993          74    2.0  80.312926         NaN            0.0     14
# 8   5172           1    2.0  64.511437         NaN            1.0      9
# 9   8649          23    1.0  46.461409   18.915552            8.0     13
#
#    HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  \
# 0         9.0       1969   0.089040         B         B        33      7976
# ...

# %% [markdown]
# ## plot

# %%
d_sort=data.sort_values("Square")

# %%
plt.plot(d_sort["Square"],d_sort["Price"])

# %%
plt.scatter(data["Square"],data["Price"])

# %%
plt.scatter(data.loc[data["Square"]<250, "Square"],
            data.loc[data["Square"]<250, "Price"])

# %%
plt.hist(data["Price"], bins=20, density=True)
# Out:
# (array([9.54606229e-07, 2.24018907e-06, 3.98217124e-06, 5.74505720e-06,
#         6.64043603e-06, 4.39676300e-06, 3.09724430e-06, 1.89876057e-06,
#         1.37964988e-06, 1.16712805e-06, 8.74475049e-07, 6.48017367e-07,
#         5.15626722e-07, 3.69300220e-07, 3.03104898e-07, 2.33425611e-07,
#         1.49810467e-07, 1.01034966e-07, 8.01311798e-08, 6.27113581e-08]),
#  array([ 59174.77802758,  87877.7124547 , 116580.64688182, 145283.58130894,
#         173986.51573605, 202689.45016317, 231392.38459029, 260095.31901741,
#         288798.25344453, 317501.18787165, 346204.12229876, 374907.05672588,
#         403609.991153  , 432312.92558012, 461015.86000724, 489718.79443436,
#         518421.72886147, 547124.66328859, 575827.59771571, 604530.53214283,
#         633233.46656995]),
#  <a list of 20 Patch objects>)

# %%
plt.hist(data["Price"], bins=[50000,100000,200000,300000,500000,700000])
# Out:
# (array([ 515., 4947., 3019., 1366.,  153.]),
#  array([ 50000, 100000, 200000, 300000, 500000, 700000]),
#  <a list of 5 Patch objects>)

# %%
sns.pairplot(data.loc[:,["Square","Price"]])

# %%
sns.pairplot(data.loc[:,["Square","KitchenSquare","Price"]], kind="reg")

# %%
sns.pairplot(data.loc[:,["Square","KitchenSquare","Price"]], kind="reg", diag_kind="kde")

# %%
sns.jointplot(data["Square"],data["Price"])

# %%
sns.jointplot(data["Square"],data["Price"], kind="reg")

# %%
sns.boxplot(data["Price"], orient='v')

# %%
sns.boxplot(data["Rooms"],data["Price"])

# %%
sns.distplot(data["Price"])
